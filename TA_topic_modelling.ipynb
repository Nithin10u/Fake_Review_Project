# %%
#importing libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF

# %%
#loading preprocessed data
data = pd.read_csv(r"C:\Users\Nithin Srinivaas\OneDrive\Documents\Fake_Review_Project\TP_DS.csv")

# %%
print(data.columns)
# Out:
# Index(['category', 'rating', 'label', 'text_', 'cleaned_text'], dtype='object')

# %%
#The reviews variable will contain only the non-null review text
# Sample DataFrame (adjust the 'cleaned_text' column as needed)
reviews = data['cleaned_text'].dropna()  # Assuming 'data' is the DataFrame with review text

# %% [markdown]
# Step 1: Text Vectorization with TF-IDF

# %%
#transforme your text data (reviews) into a numerical format (tfidf_matrix) suitable for further analysis or modeling.
tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
tfidf_matrix = tfidf_vectorizer.fit_transform(reviews)

# %% [markdown]
# Step 2: LDA and NMF for Topic Modeling

# %%
#apply two different algorithms (LDA and NMF) to identify topics in your text data
n_topics = 100 # Number of topics

# LDA Model
lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)
lda_topics = lda_model.fit_transform(tfidf_matrix)

# NMF Model
nmf_model = NMF(n_components=n_topics, random_state=42)
nmf_topics = nmf_model.fit_transform(tfidf_matrix)

# Helper function to get top words per topic
def get_top_words(model, feature_names, n_top_words=10):
    topics = {}
    for topic_idx, topic in enumerate(model.components_):
        top_words = [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
        topics[f"Topic {topic_idx + 1}"] = top_words
    return topics

# Get top words for each topic
lda_top_words = get_top_words(lda_model, tfidf_vectorizer.get_feature_names_out())
nmf_top_words = get_top_words(nmf_model, tfidf_vectorizer.get_feature_names_out())

print("LDA Topics:\n", lda_top_words)
print("NMF Topics:\n", nmf_top_words)
# Out:
# LDA Topics:
#  {'Topic 1': ['pillow', 'cheap', 'assembl', 'cook', 'accur', 'feel', 'look', 'easi', 'love', 'great'], 'Topic 2': ['dvd', 'origin', 'everyon', 'sometim', 'memori', 'compar', 'impress', 'dead', 'cours', 'movi'], 'Topic 3': ['reason', 'gave', 'star', 'ador', 'plastic', 'small', 'good', 'qualiti', 'comfort', 'materi'], 'Topic 4': ['link', 'class', 'hook', 'twist', 'predict', 'data', 'suspens', 'ref', 'norm', 'nbsp'], 'Topic 5': ['shirt', 'smell', 'pan', 'thank', 'tree', 'unless', 'great', 'use', 'love', 'like'], 'Topic 6': ['babi', 'broken', 'replac', 'bought', 'classic', 'die', 'love', 'natur', 'old', 'tv'], 'Topic 7': ['shoe', 'comfort', 'bulki', 'fit', 'toe', 'foot', 'heel', 'practic', 'look', 'love'], 'Topic 8': ['book', 'novel', 'read', 'reader', 'chain', 'histor', 'histori', 'stori', 'american', 'fiction'], 'Topic 9': ['light', 'bright', 'bathroom', 'great', 'use', 'quiet', 'color', 'work', 'fan', 'offic'], 'Topic 10': ['switch', 'trs', 'parti', 'tini', 'smart', 'lower', 'trust', 'surviv', 'use', 'work'], 'Topic 11': ['woman', 'simpl', 'friend', 'tall', 'bought', 'cost', 'strong', 'immedi', 'dream', 'relationship'], 'Topic 12': ['glass', 'band', 'fix', 'bar', 'rubber', 'way', 'plastic', 'use', 'work', 'nice'], 'Topic 13': ['gun', 'unit', 'mat', 'tea', 'compact', 'oper', 'perform', 'use', 'great', 'easi'], 'Topic 14': ['train', 'beauti', 'wooden', 'track', 'car', 'plate', 'roll', 'certainli', 'love', 'set'], 'Topic 15': ['touch', 'scratch', 'center', 'tablet', 'talk', 'murder', 'caus', 'kill', 'someon', 'screen'], 'Topic 16': ['granddaught', 'lego', 'love', 'histori', 'drill', 'old', 'th', 'set', 'best', 'year'], 'Topic 17': ['wide', 'width', 'foot', 'red', 'war', 'narrow', 'bore', 'fit', 'littl', 'perfect'], 'Topic 18': ['bed', 'steel', 'lightweight', 'stainless', 'comfort', 'easi', 'use', 'love', 'dog', 'great'], 'Topic 19': ['money', 'valu', 'wast', 'worth', 'pricey', 'deliv', 'great', 'appreci', 'buy', 'pain'], 'Topic 20': ['downsid', 'glove', 'fantast', 'futur', 'knew', 'tough', 'previou', 'thicker', 'gener', 'current'], 'Topic 21': ['filter', 'box', 'litter', 'water', 'crazi', 'cat', 'use', 'clean', 'soni', 'work'], 'Topic 22': ['tool', 'knife', 'use', 'slide', 'great', 'handl', 'work', 'good', 'nice', 'sharp'], 'Topic 23': ['instruct', 'follow', 'clear', 'poor', 'easi', 'descript', 'floor', 'design', 'use', 'includ'], 'Topic 24': ['expect', 'daughter', 'bigger', 'smaller', 'love', 'littl', 'heavier', 'wallet', 'size', 'thought'], 'Topic 25': ['amaz', 'miss', 'especi', 'awesom', 'stop', 'rest', 'book', 'spend', 'event', 'truli'], 'Topic 26': ['charact', 'stori', 'book', 'read', 'develop', 'written', 'enjoy', 'good', 'love', 'plot'], 'Topic 27': ['ship', 'fast', 'function', 'product', 'mous', 'satisfi', 'great', 'appear', 'price', 'otherwis'], 'Topic 28': ['watch', 'saw', 'tv', 'bunch', 'episod', 'volum', 'time', 'movi', 'guy', 'entir'], 'Topic 29': ['cool', 'super', 'understand', 'clip', 'parent', 'suggest', 'cute', 'share', 'role', 'mysteri'], 'Topic 30': ['gift', 'love', 'husband', 'birthday', 'christma', 'bought', 'sheet', 'son', 'great', 'daughter'], 'Topic 31': ['kitchen', 'grandson', 'tabl', 'cord', 'machin', 'purpos', 'nice', 'use', 'great', 'love'], 'Topic 32': ['ok', 'cold', 'warm', 'weather', 'hot', 'kindl', 'level', 'use', 'water', 'great'], 'Topic 33': ['card', 'updat', 'sight', 'later', 'fail', 'save', 'power', 'review', 'work', 'use'], 'Topic 34': ['lead', 'lack', 'men', 'book', 'sort', 'struggl', 'exampl', 'woman', 'read', 'discov'], 'Topic 35': ['pair', 'vacuum', 'tape', 'board', 'low', 'deep', 'arm', 'realli', 'problem', 'second'], 'Topic 36': ['dress', 'fit', 'materi', 'medium', 'larg', 'summer', 'size', 'stretchi', 'soft', 'wear'], 'Topic 37': ['cup', 'pad', 'leg', 'pant', 'knee', 'suction', 'somewhat', 'fit', 'size', 'wide'], 'Topic 38': ['len', 'bike', 'drink', 'block', 'use', 'surfac', 'good', 'great', 'camera', 'love'], 'Topic 39': ['school', 'wall', 'town', 'fli', 'mark', 'disc', 'stick', 'titl' ...
# NMF Topics:
#  {'Topic 1': ['book', 'written', 'write', 'histori', 'finish', 'inform', 'forward', 'disappoint', 'start', 'copi'], 'Topic 2': ['use', 'month', 'camera', 'issu', 'fact', 'phone', 'trs', 'pad', 'week', 'everyday'], 'Topic 3': ['movi', 'action', 'seen', 'funni', 'saw', 'entertain', 'scene', 'slow', 'dvd', 'actor'], 'Topic 4': ['love', 'absolut', 'fact', 'son', 'wife', 'granddaught', 'music', 'grandson', 'husband', 'mi'], 'Topic 5': ['fit', 'perfectli', 'tight', 'snug', 'fine', 'loo', 'dress', 'right', 'short', 'head'], 'Topic 6': ['dog', 'food', 'treat', 'eat', 'chew', 'mi', 'collar', 'har', 'chewer', 'picki'], 'Topic 7': ['stori', 'told', 'line', 'written', 'short', 'sweet', 'point', 'flow', 'view', 'pace'], 'Topic 8': ['great', 'thi', 'job', 'valu', 'addit', 'deal', 'kid', 'purchase', 'wish', 'actor'], 'Topic 9': ['good', 'veri', 'write', 'far', 'valu', 'nic', 'bad', 'overal', 'job', 'len'], 'Topic 10': ['toy', 'son', 'play', 'christma', 'absolut', 'mi', 'birthday', 'month', 'car', 'durabl'], 'Topic 11': ['light', 'bright', 'weight', 'led', 'night', 'flashlight', 'switch', 'turn', 'room', 'hous'], 'Topic 12': ['like', 'fact', 'felt', 'style', 'll', 'short', 'tast', 'ok', 'smell', 'sure'], 'Topic 13': ['work', 'fine', 'advertis', 'perfectli', 'instal', 'cabl', 'nic', 'stop', 'comput', 'far'], 'Topic 14': ['bulb', 'bright', 'led', 'instal', 'kitchen', 'lamp', 'warm', 'white', 'room', 'downsid'], 'Topic 15': ['woman', 'life', 'peopl', 'live', 'famili', 'man', 'world', 'real', 'young', 'strong'], 'Topic 16': ['qualiti', 'high', 'plea', 'amaz', 'poor', 'brand', 'profession', 'video', 'right', 'impress'], 'Topic 17': ['read', 'quick', 'definit', 'forward', 'glad', 'middl', 'admit', 'fun', 'fast', 'night'], 'Topic 18': ['reason', 'gave', 'star', 'cover', 'rate', 'flimsi', 'self', 'practic', 'given', 'gift'], 'Topic 19': ['nice', 'addit', 'solid', 'veri', 'touch', 'design', 'finish', 'extra', 'collect', 'fabric'], 'Topic 20': ['problem', 'kind', 'vacuum', 'pair', 'screw', 'updat', 'screen', 'issu', 'tini', 'fix'], 'Topic 21': ['littl', 'tight', 'pricey', 'smaller', 'wish', 'guy', 'big', 'difficult', 'loo', 'slow'], 'Topic 22': ['product', 'plea', 'link', 'ship', 'compani', 'month', 'design', 'receiv', 'issu', 'discount'], 'Topic 23': ['year', 'old', 'granddaught', 'ago', 'grandson', 'new', 'kid', 'lab', 'sever', 'older'], 'Topic 24': ['cat', 'food', 'eat', 'treat', 'litter', 'picki', 'smell', 'stuff', 'tast', 'pet'], 'Topic 25': ['size', 'right', 'larger', 'smaller', 'normal', 'true', '10', 'half', 'bigger', 'big'], 'Topic 26': ['easi', 'clean', 'instal', 'assembl', 'instruct', 'follow', 'togeth', 'super', 'carri', 'adjust'], 'Topic 27': ['day', 'everi', 'week', 'written', 'night', 'stay', 'hour', 'foot', 'took', 'minut'], 'Topic 28': ['charact', 'develop', 'plot', 'written', 'believ', 'main', 'write', 'told', 'kept', 'strong'], 'Topic 29': ['time', 'arriv', 'everi', 'sever', 'saw', 'wast', 'favorit', 'second', 'mani', 'took'], 'Topic 30': ['realli', 'vacuum', 'help', 'actual', 'cool', 'pair', 'impress', 'stand', 'bad', 'care'], 'Topic 31': ['look', 'forward', 'pictur', 'exactli', 'cheap', 'someth', 'lamp', 'bathroom', 'room', 'kitchen'], 'Topic 32': ['piec', 'sturdi', 'puzzl', 'togeth', 'contain', 'kid', 'wood', 'stand', 'assembl', 'tini'], 'Topic 33': ['seri', 'forward', 'favorit', 'continu', 'new', 'start', 'second', 'hope', 'entir', 'follow'], 'Topic 34': ['small', 'big', 'run', 'town', 'return', 'space', 'ear', 'puppi', 'heavi', 'deal'], 'Topic 35': ['lot', 'fun', 'action', 'twist', 'stuff', 'inform', 'heart', 'differ', 'sexual', 'fact'], 'Topic 36': ['set', 'lego', 'train', 'second', 'kid', 'glass', 'turn', 'togeth', 'wooden', 'sheet'], 'Topic 37': ['recommend', 'anyon', 'highli', 'definit', 'thi', 'histori', 'written', 'strong', 'everyon', 'histor'], 'Topic 38': ['perfect', 'condit', 'kitchen', 'warm', 'exactli', 'summer', 'addit', 'length', 'room', 'area'], 'Topic 39': ['materi', 'dress', 'stretchi', 'durabl', 'sturdi', 'stron ...

# %%
import pickle

# Save models and vectorizer
with open('lda_model.pkl', 'wb') as f:
    pickle.dump(lda_model, f)
with open('nmf_model.pkl', 'wb') as f:
    pickle.dump(nmf_model, f)
with open('tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf_vectorizer, f)

# %% [markdown]
# Topic Modeling, Clustering (K-Means), and Visualization (PCA & t-SNE)

# %%
#performing topic modeling, followed by clustering (via K-Means) and visualizing the results using PCA and t-SNE.

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
# Load Data
data = pd.read_csv(r"C:\Users\Nithin Srinivaas\OneDrive\Documents\Fake_Review_Project\TP_DS.csv")
reviews = data['cleaned_text'].dropna()

# %% [markdown]
# #Step 1: Text Vectorization with TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
tfidf_matrix = tfidf_vectorizer.fit_transform(reviews)

# %% [markdown]
# #Step 2: LDA and NMF for Topic Modeling

# %%
from sklearn.decomposition import LatentDirichletAllocation, NMF
n_topics = 100

# %%
# LDA Model
lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)
lda_topics = lda_model.fit_transform(tfidf_matrix)

# %% [markdown]
# #step 3: Apply K-Means Clustering on Topic Model Features

# %%
num_clusters = 5
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans_labels = kmeans.fit_predict(lda_topics)  # Using LDA topic distribution for clustering

# %% [markdown]
# #Step 4: Visualize Clusters using PCA or t-SNE

# %%
# Using PCA for dimensionality reduction
pca = PCA(n_components=2)
pca_components = pca.fit_transform(lda_topics)

plt.figure(figsize=(10, 7))
plt.scatter(pca_components[:, 0], pca_components[:, 1], c=kmeans_labels, cmap='plasma', s=15)
plt.title("K-Means Clustering of Reviews (PCA)")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.colorbar(label="Cluster")
plt.show()

# %%
# Using t-SNE for dimensionality reduction (optional)
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
tsne_components = tsne.fit_transform(lda_topics)

plt.figure(figsize=(10, 7))
plt.scatter(tsne_components[:, 0], tsne_components[:, 1], c=kmeans_labels, cmap='viridis', s=25)
plt.title("K-Means Clustering of Reviews (t-SNE)")
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.colorbar(label="Cluster")
plt.show()
